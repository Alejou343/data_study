# %%
import numpy as np

# %%
# The propertie dtype is using by assing a data type to values in the array
arr = np.array([1,2,3,4], dtype='float64')
arr.dtype
# Out:
# dtype('float64')

# %%
# Another way to create an array with these types of data
new = arr.astype(np.float64)            # --> También: bool_, string_, int8...
